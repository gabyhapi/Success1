# %% [markdown]
# # Module 4 Exercises - Data Visualization

# %% [markdown]
# ### Exercise 1:
#
# From the datasets folder, load the "dvddata.xlsx" file as a dataframe. Then rename the following columns (new column name is in parentheses):
# - \# of Clients (Clients)
# - Visits to each Client per Month (Visits)
# - Calls to each Client per month (Calls)
# - Emails to each Client per month (Emails)
# - \# of businesses in district (Business)

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
location="datasets/dvddata.xlsx"
dvdata = pd.read_excel(location)

# %%
dvdata.columns
# Out:
# Index(['Salesperson', 'District', 'Region', 'Sales', '# of Clients',
#        ' Visits to each Client per Month', 'Calls to each Client per month',
#        'Emails to each Client per month', '# of businesses in district'],
#       dtype='object')

# %%
dvdata.rename(columns={'# of Clients': 'Clients',
                       ' Visits to each Client per Month' :'Visits',
                       'Calls to each Client per month' : 'Calls',
                       'Emails to each Client per month': 'Emails',
                       '# of businesses in district' : 'Business'}, inplace = True)

# %%
dvdata.head()
# Out:
#        Salesperson  District Region  Sales  Clients  Visits  Calls  Emails  \
# 0     Addie Miller        52      A    393       16       2      4      30
# 1     Addie Miller        67      A    267       11       2      1      14
# 2     Addie Miller       104      A    148        4       1      1      17
# 3  Alexandra Jones        49      A    317       17       0      7       1
# 4   Alonzo Tennant        46      A    276       16       2      2      22
#
#    Business
# 0       500
# 1       627
# 2       778
# 3       530
# 4       770

# %%
dvdata.columns
# Out:
# Index(['Salesperson', 'District', 'Region', 'Sales', 'Clients', 'Visits',
#        'Calls', 'Emails', 'Business'],
#       dtype='object')

# %% [markdown]
# ### Exercise 2:
#
# Using the dataframe from the previous exercise, use the Seaborn library to create a scatterplot of the number of clients compared to the sales.

# %%
sns.lmplot(x='Clients', y='Sales', data=dvdata)

# %% [markdown]
# ### Exercise 3:
#
# Using the dataframe in the previous exercise, use the Seaborn library to make a boxplot of the Clients, Visits, Calls, and Emails columns. (**Hint**: Make a dataframe that only contains those columns)

# %%
dvddata=dvdata.drop ('District',axis=1)

# %%
dvsdata=dvddata.drop ('Sales', axis=1)
dvidata=dvsdata.drop ('Business', axis=1)

dvidata
# Out:
#             Salesperson Region  Clients  Visits  Calls  Emails
# 0          Addie Miller      A       16       2      4      30
# 1          Addie Miller      A       11       2      1      14
# 2          Addie Miller      A        4       1      1      17
# 3       Alexandra Jones      A       17       0      7       1
# 4        Alonzo Tennant      A       16       2      2      22
# 5        Alonzo Tennant      A       16       2      8      21
# 6        Alonzo Tennant      A       11       1      1       3
# 7         Andrea Kraatz      A       13       2      6      11
# 8         Ann Dominguez      A        4       2      5      29
# 9            Anna Desai      A        4       2      6      26
# 10        Barbara Wales      A       19       2      1      25
# 11        Barbara Wales      A       10       1      0      10
# 12         Bessie Lewis      A       13       2      0      26
# 13         Bessie Lukas      A       13       1      4       5
# 14       Bessie Mcmanus      A       15       2      0      11
# 15       Bessie Mcmanus      A        7       2      7      26
# 16       Bessie Mcmanus      A       22       0      2       3
# 17        Caroline Boyd      A       20       0      7      23
# 18    Charlotte Simmons      A       17       0      6      10
# 19    Charlotte Simmons      A       22       0      6      18
# 20       Charmain Crisp      A       21       2      3      30
# 21      Christine Lopez      A        2       0      5       3
# 22  Christopher Alvardo      A        8       1      0      20
# 23  Christopher Alvardo      A        5       2      7      28
# 24      Connie Douglass      B       12       2      2       4
# 25      Cynthia Conklin      B       22       0      0      24
# 26      Cynthia Conklin      B       10       2      6      14
# 27      Cynthia Ellison      B       16       0      0       1
# 28        Deborah Seals      B        9       1      7       1
# 29        Deborah Seals      B       21       1      0      29
# ..                  ...    ...      ...     ...    ...     ...
# 70           Lorna Kyle      C        4       1      7      19
# 71      Margaret Cooper      C       10       0      6       7
# 72      Margie Thrasher      C       21       1      7      17
# 73      Marilyn Sandler      C       11       2      6      10
# 74        Marisol Rosen      C        9       2      0       2
# 75        Martha Fabian      D       11       1      5      20
# 76         Mary Adamson      D       19       0      5      27
# 77        Mary Gauthier      D       12       0      6      29
# 78           Mary Smith      D        2       1      0      20
# 79          Megan Gault      D       14       1      4       0
# 80         Moses Chavez      D       10       1      5      27
# 81          Myrna Ellis      D       18       2      0      27
# 82         Nina Kennedy      D       16       2      8       3
# 83       Pamala Darrell      D       21       1      2      17
# 84      Rachel Griffith      D       18       0      7      11
# 85        Robert Liston      D        4       1      6       4
# 86        Ruby Meyerson      D        5       0      1      21
# 87       Sally Vineyard      D       20       1      2      11
# 88        Samuel Cuyler      D       19       1      3      18
# 89          Sarah Ellis      D       20       0      7      13
# 90           Sarah Hall      D        6       2      5      22
# 91     Sherry Davenport      D       15       2      3      27
# 92         Shirley Vick      D       22       1      1      16
# 93       Sonia Greenman      D       22       0      0       4
# 94        Susan J. Ward      D       11       2      3      10
# 95        Tammy Stowers      D       15       0      2      26
# 96         Terri Taylor      D       11       2      2       9
# 97         Terry Bonner      D        8       2      8      18
# 98        Terry Donnell      D       22       1      6      21
# 99        Trudy Vaughan      D       22       1      5      20
#
# [100 rows x 6 columns]

# %%
sns.boxplot(data=dvidata)

# %% [markdown]
# ### Exercise 4:
#
# Using the dataframe from Exercise 3, use the Seaborn library to make a violin plot of sales per region.

# %%
plt.subplots(figsize=(13,7))
sns.violinplot(x='Region', y='Sales', data=dvdata)

# %% [markdown]
# ### Exercise 5:
#
# Using the dataframe in the previous exercise, create a swarm plot of sales per region.

# %%
plt.subplots(figsize=(10,6))
sns.swarmplot(x='Region', y='Sales', data=dvdata)

# %% [markdown]
# ### Exercise 6:
#
# Using the dataframe in the previous exercise, make a correlation heatmap.

# %%
corr = dvdata.corr()

sns.heatmap(corr, vmin=-1, annot=True)

# %% [markdown]
# ### Exercise 7:
#
# Using the dataframe in the previous exercise, make a bar chart (count plot) of the regions.

# %%
sns.countplot(x='Region',
              data=dvdata)

plt.xticks(rotation=-45)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text xticklabel objects>)

# %% [markdown]
# ### Bonus
#
# Feel free to explore any other data visualizations using the Seaborn library.
